# %%
import pandas as pd
import json
import io

# %%
file_path = 'updated_winery_dataset.csv'
df = pd.read_csv(file_path)

# %%
df
# Out:
#         Unnamed: 0  country  \
# 0                0       US
# 1                1    Spain
# 2                2       US
# 3                3       US
# 4                4   France
# ...            ...      ...
# 258140      129966  Germany
# 258141      129967       US
# 258142      129968   France
# 258143      129969   France
# 258144      129970   France
#
#                                               description  points  price  \
# 0       This tremendous 100% varietal wine hails from ...      96  235.0
# 1       Ripe aromas of fig, blackberry and cassis are ...      96  110.0
# 2       Mac Watson honors the memory of a wine once ma...      96   90.0
# 3       This spent 20 months in 30% new French oak, an...      96   65.0
# 4       This is the top wine from La Bégude, named aft...      95   66.0
# ...                                                   ...     ...    ...
# 258140  Notes of honeysuckle and cantaloupe sweeten th...      90   28.0
# 258141  Citation is given as much as a decade of bottl...      90   75.0
# 258142  Well-drained gravel soil gives this wine its c...      90   30.0
# 258143  A dry style of Pinot Gris, this is crisp with ...      90   32.0
# 258144  Big, rich and off-dry, this is powered by inte...      90   21.0
#
#               province             variety  \
# 0           California  Cabernet Sauvignon
# 1       Northern Spain       Tinta de Toro
# 2           California     Sauvignon Blanc
# 3               Oregon          Pinot Noir
# 4             Provence  Provence red blend
# ...                ...                 ...
# 258140           Mosel            Riesling
# 258141          Oregon          Pinot Noir
# 258142          Alsace      Gewürztraminer
# 258143          Alsace          Pinot Gris
# 258144          Alsace      Gewürztraminer
#
#                                           winery
# 0                                          Heitz
# 1                        Bodega Carmen Rodríguez
# 2                                       Macauley
# 3                                          Ponzi
# 4                           Domaine de la Bégude
# ...                                          ...
# 258140  Dr. H. Thanisch (Erben Müller-Burggraef)
# 258141                                  Citation
# 258142                           Domaine Gresser
# 258143                      Domaine Marcel Deiss
# 258144                          Domaine Schoffit
#
# [258145 rows x 8 columns]

# %%
# I was getting a runtime: out of memory error when running the model on the entire dataset so I filtered by province
# for only california wines. comment out the code below to run on the entire dataset.
new_df = df.loc[df['province'] == 'California']

# %%
new_df = new_df[['points', 'price', 'province', 'variety', 'winery']]

# %%
new_df
# Out:
#         points  price    province             variety         winery
# 0           96  235.0  California  Cabernet Sauvignon          Heitz
# 2           96   90.0  California     Sauvignon Blanc       Macauley
# 9           95   60.0  California          Pinot Noir      Blue Farm
# 16          95  325.0  California  Cabernet Sauvignon           Hall
# 19          95   75.0  California          Pinot Noir   Gary Farrell
# ...        ...    ...         ...                 ...            ...
# 258117      90   35.0  California  Cabernet Sauvignon       Arrowood
# 258120      90   20.0  California        Chenin Blanc      Birichino
# 258124      90   35.0  California          Chardonnay  Flora Springs
# 258125      90   35.0  California           Zinfandel         Hendry
# 258127      90   22.0  California           Zinfandel        Houdini
#
# [80460 rows x 5 columns]

# %%
data = new_df.values
X = data[:, 0:2]
province = data[:, 2]
variety = data[:, 3]
winery = data[:, 4]
winery
# Out:
# array(['Heitz', 'Macauley', 'Blue Farm', ..., 'Flora Springs', 'Hendry',
#        'Houdini'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# Step 1: Label-encode data set
label_encoder = LabelEncoder()
label_encoder.fit(variety)
encoded_variety = label_encoder.transform(variety)
encoded_variety
# Out:
# array([ 21, 143, 119, ...,  37, 201, 201])

# %%
label_encoder.fit(province)
encoded_province = label_encoder.transform(province)
encoded_province
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
label_encoder.fit(winery)
encoded_winery = label_encoder.transform(winery)

# %%
X = new_df['price']
Y = encoded_winery

# %%
encoded_province.max()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
plt.scatter(X, Y)

# %%
# for label, original_class in zip(encoded_y, y):
#     print('Original Class: ' + str(original_class))
#     print('Encoded Label: ' + str(label))
#     print('-' * 12)

# %%
# from keras.utils import to_categorical

# # Step 2: One-hot encoding
# one_hot_y = to_categorical(encoded_y)
# one_hot_y

# %%
newest = {
    'price': new_df['price'],
    'points': new_df['points'],
    'variety': encoded_variety.tolist(),
#     'province': encoded_province.tolist(),
    'winery': encoded_winery.tolist()
    
}
newest
# Out:
# {'price': 0         235.0
#  2          90.0
#  9          60.0
#  16        325.0
#  19         75.0
#            ...
#  258117     35.0
#  258120     20.0
#  258124     35.0
#  258125     35.0
#  258127     22.0
#  Name: price, Length: 80460, dtype: float64,
#  'points': 0         96
#  2         96
#  9         95
#  16        95
#  19        95
#            ..
#  258117    90
#  258120    90
#  258124    90
#  258125    90
#  258127    90
#  Name: points, Length: 80460, dtype: int64,
#  'variety': [21,
#   143,
#   119,
#   21,
#   119,
#   133,
#   37,
#   119,
#   119,
#   37,
#   21,
#   37,
#   159,
#   21,
#   21,
#   21,
#   119,
#   143,
#   21,
#   21,
#   119,
#   80,
#   21,
#   37,
#   37,
#   21,
#   192,
#   21,
#   23,
#   89,
#   17,
#   37,
#   198,
#   37,
#   21,
#   119,
#   119,
#   156,
#   37,
#   119,
#   119,
#   201,
#   21,
#   37,
#   9,
#   37,
#   21,
#   62,
#   201,
#   127,
#   143,
#   62,
#   2,
#   119,
#   201,
#   159,
#   75,
#   13,
#   159,
#   192,
#   37,
#   119,
#   119,
#   21,
#   37,
#   159,
#   119,
#   201,
#   201,
#   37,
#   201,
#   91,
#   201,
#   159,
#   159,
#   21,
#   37,
#   37,
#   128,
#   81,
#   119,
#   143,
#   119,
#   26,
#   125,
#   114,
#   91,
#   37,
#   37,
#   127,
#   156,
#   119,
#   119,
#   21,
#   159,
#   159,
#   119,
#   119,
#   201,
#   130,
#   130,
#   119,
#   119,
#   119,
#   119,
#   21,
#   21,
#   156,
#   21,
#   21,
#   143,
#   128,
#   159,
#   21,
#   119,
#   37,
#   37,
#   37,
#   37,
#   125,
#   186,
#   21,
#   21,
#   81,
#   125,
#   21,
#   21,
#   127,
#   21,
#   37,
#   21,
#   198,
#   21,
#   143,
#   37,
#   37,
#   37,
#   21,
#   127,
#   174,
#   201,
#   37,
#   21,
#   21,
#   37,
#   159,
#   89,
#   1,
#   21,
#   192,
#   119,
#   37,
#   143,
#   123,
#   119,
#   125,
#   9,
#   119,
#   13,
#   125,
#   159,
#   201,
#   201,
#   37,
#   201,
#   13,
#   21,
#   125,
#   37,
#   37,
#   159,
#   37,
#   37,
#   192,
#   37,
#   37,
#   17,
#   201,
#   119,
#   119,
#   33,
#   201,
#   37,
#   21,
#   81,
#   21,
#   21,
#   119,
#   21,
#   37,
#   37,
#   119,
#   119,
#   21,
#   119,
#   159,
#   37,
#   201,
#   37,
#   21,
#   21,
#   201,
#   201,
#   21,
#   119,
#   37,
#   37,
#   125,
#   119,
#   143,
#   21,
#   13,
#   59,
#   119,
#   128,
#   21,
#   62,
#   80,
#   62,
#   37,
#   119,
#   59,
#   119,
#   192,
#   37,
#   81,
#   37,
#   119,
#   21,
#   37,
#   119,
#   119,
#   37,
#   143,
#   125,
#   37,
#   17,
#   139,
#   201,
#   143,
#   36,
#   21,
#   174,
#   125,
#   125,
#   21,
#   21,
#   81,
#   21,
#   37,
#   130,
#   37,
#   174,
#   107,
#   56,
#   159,
#   125,
#   13,
#   123,
#   125,
#   143,
#   21,
#   159,
#   111,
#   201,
#   125,
#   21,
#   37,
#   21,
#   130,
#   81,
#   21,
#   103,
#   91,
#   9,
#   125,
#   174,
#   127,
#   201,
#   159,
#   17,
#   21,
#   81,
#   21,
#   119,
#   119,
#   174,
#   21,
#   37,
#   37,
#   201,
#   37,
#   159,
#   21,
#   162,
#   127,
#   125,
#   37,
#   159,
#   37,
#   159,
#   37,
#   21,
#   143,
#   125,
#   21,
#   159,
#   156,
#   159,
#   119,
#   37,
#   119,
#   119,
#   125,
#   37,
#   127,
#   156,
#   21,
#   119,
#   125,
#   119,
#   119,
#   37,
#   37,
#   21,
#   37,
#   37,
#   114,
#   21,
#   37,
#   119,
#   159,
#   119,
#   119,
#   81,
#   13,
#   91,
#   201,
#   37,
#   55,
#   119,
#   119,
#   81,
#   21,
#   130,
#   37,
#   13,
#   198,
#   198,
#   134,
#   21,
#   21,
#   143,
#   21,
#   91,
#   62,
#   37,
#   143,
#   159,
#   21,
#   37,
#   59,
#   17,
#   37,
#   119,
#   37,
#   37,
#   73,
#   122,
#   143,
#   125,
#   21,
#   37,
#   133,
#   21,
#   159,
#   119,
#   37,
#   159,
#   119,
#   21,
#   198,
#   119,
#   37,
#   62,
#   119,
#   119,
#   21,
#   201,
#   198,
#   21,
#   125,
#   128,
#   37,
#   21,
#   37,
#   159,
#   21,
#   13,
#   37,
#   21,
#   37,
#   21,
#   139,
#   37,
#   201,
#   37,
#   130,
#   37,
#   201,
#   143,
#   84,
#   125,
#   119,
#   91,
#   80,
#   133,
#   13,
#   62,
#   201,
#   123,
#   159,
#   201,
#   37,
#   119,
#   119,
#   127,
#   37,
#   119,
#   21,
#   119,
#   119,
#   116,
#   108,
#   192,
#   125,
#   119,
#   119,
#   21,
#   159,
#   127,
#   201,
#   119,
#   21,
#   201,
#   37,
#   133,
#   201,
#   125,
#   201,
#   201,
#   127,
#   142,
#   190,
#   119,
#   37,
#   119,
#   21,
#   21,
#   17,
#   125,
#   21,
#   119,
#   37,
#   125,
#   159,
#   201,
#   127,
#   37,
#   21,
#   21,
#   143,
#   143,
#   62,
#   21,
#   62,
#   119,
#   119,
#   174,
#   198,
#   156,
#   9,
#   108,
#   201,
#   201,
#   144,
#   119,
#   198,
#   143,
#   119,
#   159,
#   13,
#   143,
#   201,
#   159,
#   37,
#   21,
#   174,
#   159,
#   37,
#   37,
#   139,
#   21,
#   37,
#   201,
#   37,
#   156,
#   81,
#   201,
#   59,
#   37,
#   21,
#   81,
#   119,
#   201,
#   37,
#   119,
#   119,
#   21,
#   125,
#   127,
#   37,
#   130,
#   91,
#   125,
#   156,
#   119,
#   37,
#   133,
#   37,
#   125,
#   127,
#   21,
#   201,
#   81,
#   108,
#   119,
#   143,
#   128,
#   143,
#   119,
#   201,
#   143,
#   119,
#   201,
#   37,
#   17,
#   156,
#   201,
#   201,
#   127,
#   159,
#   62,
#   37,
#   159,
#   119,
#   119,
#   201,
#   201,
#   119,
#   119,
#   4,
#   62,
#   159,
#   159,
#   37,
#   133,
#   143,
#   21,
#   37,
#   128,
#   21,
#   81,
#   192,
#   62,
#   21,
#   201,
#   21,
#   119,
#   21,
#   13,
#   125,
#   201,
#   21,
#   201,
#   198,
#   37,
#   21,
#   21,
#   21,
#   143,
#   116,
#   37,
#   201,
#   143,
#   159,
#   201,
#   21,
#   37,
#   21,
#   119,
#   119,
#   130,
#   201,
#   119,
#   201,
#   37,
#   21,
#   37,
#   21,
#   81,
#   80,
#   119,
#   21,
#   21,
#   119,
#   21,
#   13,
#   21,
#   119,
#   37,
#   119,
#   119,
#   37,
#   119,
#   159,
#   13,
#   107,
#   125,
#   21,
#   9,
#   33,
#   201,
#   37,
#   37,
#   21,
#   201,
#   127,
#   119,
#   119,
#   159,
#   119,
#   119,
#   36,
#   192,
#   125,
#   174,
#   21,
#   125,
#   21,
#   108,
#   201,
#   37,
#   21,
#   33,
#   127,
#   81,
#   143,
#   21,
#   21,
#   119,
#   21,
#   119,
#   130,
#   201,
#   119,
#   201,
#   37,
#   81,
#   21,
#   37,
#   119,
#   119,
#   119,
#   37,
#   21,
#   73,
#   37,
#   201,
#   201,
#   201,
#   37,
#   119,
#   2,
#   119,
#   201,
#   133,
#   119,
#   108,
#   119,
#   119,
#   133,
#   143,
#   119,
#   119,
#   201,
#   21,
#   37,
#   21,
#   159,
#   166,
#   159,
#   26,
#   60,
#   62,
#   159,
#   159,
#   143,
#   125,
#   33,
#   127,
#   81,
#   143,
#   159,
#   162,
#   119,
#   159,
#   21,
#   119,
#   201,
#   119,
#   159,
#   21,
#   143,
#   119,
#   13,
#   201,
#   201,
#   201,
#   21,
#   9,
#   143,
#   41,
#   125,
#   119,
#   143,
#   133,
#   37,
#   108,
#   80,
#   21,
#   125,
#   119,
#   159,
#   159,
#   119,
#   119,
#   201,
#   37,
#   189,
#   21,
#   21,
#   37,
#   17,
#   21,
#   125,
#   91,
#   125,
#   128,
#   156,
#   73,
#   81,
#   62,
#   159,
#   21,
#   21,
#   21,
#   17,
#   198,
#   198,
#   37,
#   37,
#   130,
#   125,
#   37,
#   36,
#   37,
#   37,
#   128,
#   125,
#   21,
#   143,
#   119,
#   21,
#   21,
#   37,
#   37,
#   159,
#   201,
#   174,
#   123,
#   21,
#   119,
#   21,
#   119,
#   21,
#   143,
#   143,
#   37,
#   119,
#   119,
#   119,
#   21,
#   143,
#   159,
#   192,
#   159,
#   37,
#   201,
#   159,
#   21,
#   119,
#   125,
#   119,
#   81,
#   143,
#   37,
#   119,
#   156,
#   119,
#   143,
#   21,
#   119,
#   119,
#   119,
#   119,
#   201,
#   37,
#   119,
#   119,
#   21,
#   21,
#   21,
#   37,
#   37,
#   114,
#   21,
#   21,
#   159,
#   139,
#   37,
#   9,
#   13,
#   21,
#   159,
#   159,
#   119,
#   159,
#   159,
#   128,
#   37,
#   139,
#   81,
#   17,
#   108,
#   119,
#   143,
#   159,
#   192,
#   159,
#   37,
#   37,
#   159,
#   201,
#   125,
#   119,
#   127,
#   143,
#   108,
#   163,
#   73,
#   13,
#   125,
#   37,
#   37,
#   159,
#   21,
#   201,
#   37,
#   37,
#   125,
#   125,
#   119,
#   37,
#   159,
#   2,
#   21,
#   201,
#   21,
#   81,
#   119,
#   21,
#   119,
#   37,
#   119,
#   159,
#   192,
#   125,
#   192,
#   73,
#   143,
#   192,
#   37,
#   81,
#   37,
#   159,
#   91,
#   62,
#   119,
#   159,
#   119,
#   119,
#   119,
#   119,
#   119,
#   119,
#   119,
#   119,
#   37,
#   37,
#   37,
#   37,
#   119,
#   21,
#   143,
#   125,
#   119,
#   144,
#   21,
#   201,
#   21,
#   116,
#   119,
#   201,
#   119,
#   127,
#   67,
#   62,
#   201,
#   21,
#   21,
#   21,
#   37,
#   17,
#   143,
#   21,
#   201,
#   127,
#   139,
#   21,
#   159,
#   17,
#   125,
#   37,
#   143,
#   127,
#   143,
#   192,
#   119,
#   119,
#   143,
#   119,
#   81,
#   119,
#   13,
#   37,
#   21,
#   119,
#   125,
#   119,
#   125,
#   59,
#   192,
#   198,
#   37,
#   119,
#   21,
#   119,
#   21,
#   26,
#   37,
#   192,
#   21,
#   125,
#   17,
#   201,
#   21,
#   201,
#   9,
#   119,
#   119,
#   119,
#   119,
#   37,
#   119,
#   13,
#   125,
#   119,
#   37,
#   37,
#   ...],
#  'winery': [1759,
#   2386,
#   451,
#   1689,
#   1561,
#   1759,
#   743,
#   899,
#   3281,
#   4439,
#   508,
#   1071,
#   1973,
#   2574,
#   3105,
#   3186,
#   3195,
#   266,
#   267,
#   1229,
#   1277,
#   1500,
#   365,
#   2919,
#   3950,
#   4006,
#   1735,
#   1781,
#   1259,
#   1223,
#   1912,
#   2238,
#   2105,
#   2127,
#   773,
#   2384,
#   1490,
#   1605,
#   1650,
#   2729,
#   2729,
#   3234,
#   4068,
#   92,
#   150,
#   381,
#   338,
#   521,
#   2956,
#   3984,
#   856,
#   3432,
#   3768,
#   1613,
#   1650,
#   2084,
#   2202,
#   1494,
#   2487,
#   1241,
#   2811,
#   3425,
#   1490,
#   644,
#   3320,
#   3417,
#   3569,
#   4017,
#   4017,
#   1619,
#   3283,
#   163,
#   3283,
#   3195,
#   2686,
#   1125,
#   872,
#   1037,
#   1066,
#   1085,
#   3404,
#   3727,
#   3912,
#   2862,
#   2862,
#   313,
#   64,
#   103,
#   1351,
#   1542,
#   1920,
#   2256,
#   3381,
#   900,
#   285,
#   1948,
#   528,
#   1001,
#   1071,
#   3643,
#   3794,
#   3912,
#   428,
#   451,
#   1561,
#   2914,
#   3457,
#   3468,
#   2968,
#   1537,
#   1652,
#   1956,
#   2220,
#   2574,
#   3636,
#   3912,
#   3976,
#   4310,
#   385,
#   2231,
#   2892,
#   1684,
#   2363,
#   2711,
#   2912,
#   1506,
#   2007,
#   3101,
#   459,
#   1750,
#   1851,
#   678,
#   2528,
#   2937,
#   2942,
#   4066,
#   3897,
#   3922,
#   4322,
#   1375,
#   2236,
#   2516,
#   2571,
#   4220,
#   2220,
#   1735,
#   3950,
#   2860,
#   4367,
#   712,
#   159,
#   1241,
#   1406,
#   1077,
#   1664,
#   1735,
#   2860,
#   1490,
#   504,
#   671,
#   3260,
#   1309,
#   2311,
#   2476,
#   3283,
#   3516,
#   4231,
#   1376,
#   3427,
#   3166,
#   4210,
#   2178,
#   2366,
#   3312,
#   585,
#   1467,
#   1238,
#   1238,
#   2383,
#   2384,
#   2507,
#   2850,
#   3732,
#   459,
#   752,
#   1684,
#   2363,
#   3922,
#   1501,
#   146,
#   307,
#   1104,
#   797,
#   177,
#   272,
#   2752,
#   2914,
#   3234,
#   3369,
#   3457,
#   3921,
#   1718,
#   3312,
#   4270,
#   340,
#   1920,
#   2155,
#   2183,
#   2256,
#   385,
#   2335,
#   218,
#   293,
#   758,
#   1066,
#   1277,
#   2110,
#   1197,
#   1307,
#   1437,
#   1613,
#   1668,
#   2177,
#   2342,
#   758,
#   794,
#   1001,
#   1001,
#   2116,
#   1315,
#   1381,
#   1381,
#   2162,
#   2442,
#   2377,
#   2553,
#   2638,
#   2761,
#   2865,
#   2865,
#   3439,
#   4155,
#   2487,
#   3950,
#   3359,
#   1951,
#   2606,
#   3950,
#   3701,
#   1824,
#   2040,
#   2152,
#   2317,
#   2844,
#   3101,
#   3825,
#   256,
#   1796,
#   1198,
#   1301,
#   928,
#   472,
#   644,
#   2205,
#   2393,
#   2460,
#   2961,
#   3732,
#   3913,
#   4058,
#   1767,
#   2259,
#   2632,
#   2655,
#   2704,
#   2912,
#   3234,
#   65,
#   356,
#   752,
#   2811,
#   2116,
#   3752,
#   4058,
#   563,
#   784,
#   2487,
#   1223,
#   1467,
#   585,
#   3283,
#   3859,
#   899,
#   924,
#   1307,
#   1493,
#   3533,
#   1335,
#   758,
#   2554,
#   3612,
#   3922,
#   1042,
#   1044,
#   1110,
#   1506,
#   1712,
#   3468,
#   4302,
#   272,
#   272,
#   451,
#   755,
#   256,
#   910,
#   1375,
#   2177,
#   3868,
#   4419,
#   3184,
#   3636,
#   3763,
#   3976,
#   4310,
#   262,
#   245,
#   4229,
#   3950,
#   773,
#   3976,
#   2518,
#   2896,
#   1351,
#   2155,
#   3293,
#   4155,
#   4386,
#   719,
#   1088,
#   3293,
#   3469,
#   3877,
#   3532,
#   3532,
#   294,
#   585,
#   1668,
#   2105,
#   2692,
#   3439,
#   3778,
#   2961,
#   2937,
#   3622,
#   65,
#   703,
#   3459,
#   2865,
#   2964,
#   3516,
#   3631,
#   3782,
#   785,
#   2324,
#   2384,
#   2411,
#   2485,
#   2704,
#   3287,
#   3287,
#   4084,
#   4155,
#   4355,
#   60,
#   179,
#   4302,
#   1381,
#   1650,
#   1712,
#   3410,
#   3643,
#   307,
#   755,
#   1348,
#   2111,
#   3912,
#   864,
#   2257,
#   2906,
#   2929,
#   3186,
#   3193,
#   3850,
#   2366,
#   3659,
#   4045,
#   266,
#   773,
#   2584,
#   1150,
#   1779,
#   2366,
#   3088,
#   374,
#   91,
#   2506,
#   1085,
#   294,
#   585,
#   752,
#   1490,
#   2065,
#   953,
#   3401,
#   2315,
#   1357,
#   1694,
#   1744,
#   1172,
#   1241,
#   2387,
#   2442,
#   1216,
#   1351,
#   1430,
#   378,
#   120,
#   1972,
#   3912,
#   3114,
#   3201,
#   1454,
#   2382,
#   2607,
#   2488,
#   2377,
#   2729,
#   3763,
#   1238,
#   1381,
#   153,
#   2323,
#   2384,
#   1776,
#   1849,
#   1920,
#   2044,
#   2711,
#   2912,
#   2996,
#   3752,
#   1066,
#   3783,
#   282,
#   1505,
#   2129,
#   2169,
#   2476,
#   2476,
#   2801,
#   3142,
#   1520,
#   1806,
#   2065,
#   2445,
#   2571,
#   690,
#   863,
#   1197,
#   2215,
#   2489,
#   2554,
#   507,
#   2442,
#   4476,
#   2025,
#   141,
#   272,
#   331,
#   2495,
#   2688,
#   3018,
#   3018,
#   3234,
#   3457,
#   2723,
#   50,
#   2205,
#   1223,
#   3421,
#   137,
#   1042,
#   2549,
#   3818,
#   4432,
#   1500,
#   1647,
#   1835,
#   2474,
#   780,
#   3859,
#   3018,
#   3088,
#   721,
#   482,
#   1253,
#   1499,
#   1533,
#   1627,
#   2729,
#   3852,
#   1776,
#   1972,
#   2161,
#   2387,
#   2518,
#   528,
#   624,
#   4076,
#   2896,
#   285,
#   340,
#   4470,
#   1956,
#   2154,
#   2177,
#   2191,
#   3723,
#   3850,
#   4412,
#   256,
#   4178,
#   3779,
#   4300,
#   4355,
#   1283,
#   1707,
#   1828,
#   484,
#   871,
#   293,
#   3752,
#   2217,
#   2384,
#   1238,
#   1253,
#   1576,
#   103,
#   374,
#   1629,
#   4471,
#   3545,
#   703,
#   2999,
#   2942,
#   2048,
#   2172,
#   2206,
#   2928,
#   3426,
#   3922,
#   676,
#   2025,
#   272,
#   4476,
#   1444,
#   2025,
#   2028,
#   2489,
#   2587,
#   2633,
#   1543,
#   1047,
#   2989,
#   3142,
#   3186,
#   3312,
#   1459,
#   3763,
#   1259,
#   3701,
#   1534,
#   2506,
#   1980,
#   1077,
#   2704,
#   2900,
#   1125,
#   433,
#   507,
#   4351,
#   1348,
#   2309,
#   3283,
#   4161,
#   2571,
#   1197,
#   872,
#   4313,
#   2238,
#   4439,
#   1524,
#   2075,
#   2430,
#   2451,
#   2522,
#   2691,
#   600,
#   1174,
#   2033,
#   2075,
#   2098,
#   428,
#   952,
#   308,
#   552,
#   937,
#   1972,
#   3376,
#   1406,
#   2999,
#   3404,
#   692,
#   293,
#   1132,
#   1640,
#   1691,
#   2711,
#   2912,
#   2970,
#   468,
#   1174,
#   2956,
#   3912,
#   1174,
#   1650,
#   4476,
#   1307,
#   1381,
#   1811,
#   2022,
#   1381,
#   1444,
#   3817,
#   485,
#   784,
#   1373,
#   1459,
#   870,
#   937,
#   951,
#   1085,
#   1533,
#   1965,
#   2675,
#   2675,
#   2885,
#   3386,
#   4313,
#   704,
#   4359,
#   600,
#   1524,
#   2075,
#   2430,
#   2451,
#   2522,
#   2691,
#   3027,
#   3032,
#   3439,
#   4439,
#   246,
#   552,
#   3645,
#   182,
#   4426,
#   2487,
#   3261,
#   4155,
#   1392,
#   2148,
#   2518,
#   637,
#   3800,
#   4076,
#   3036,
#   1253,
#   1390,
#   1499,
#   1499,
#   1519,
#   1709,
#   2222,
#   411,
#   3653,
#   3701,
#   3912,
#   2668,
#   4045,
#   163,
#   632,
#   3740,
#   3139,
#   3142,
#   3195,
#   1381,
#   2691,
#   632,
#   2675,
#   2675,
#   2885,
#   3386,
#   573,
#   632,
#   1102,
#   1277,
#   4245,
#   145,
#   331,
#   2019,
#   1307,
#   3086,
#   272,
#   451,
#   2968,
#   3234,
#   3369,
#   1423,
#   3516,
#   118,
#   3564,
#   2196,
#   2231,
#   4317,
#   2811,
#   1750,
#   2324,
#   3104,
#   3287,
#   3902,
#   2693,
#   200,
#   1309,
#   3782,
#   200,
#   4359,
#   2108,
#   1166,
#   1375,
#   3287,
#   3994,
#   4161,
#   504,
#   1047,
#   4241,
#   2655,
#   1694,
#   1750,
#   2115,
#   3177,
#   3377,
#   3142,
#   3195,
#   2585,
#   3046,
#   3233,
#   3779,
#   4233,
#   1283,
#   3166,
#   3199,
#   1218,
#   1381,
#   398,
#   1897,
#   2148,
#   2256,
#   2585,
#   3319,
#   3086,
#   272,
#   451,
#   266,
#   3878,
#   1522,
#   2022,
#   2107,
#   3234,
#   3244,
#   3431,
#   3457,
#   3912,
#   177,
#   2903,
#   1328,
#   2023,
#   2075,
#   2222,
#   2451,
#   719,
#   4155,
#   292,
#   224,
#   840,
#   1381,
#   1499,
#   2928,
#   2989,
#   3369,
#   3408,
#   3763,
#   3202,
#   3233,
#   1512,
#   2811,
#   530,
#   624,
#   3696,
#   2384,
#   4432,
#   1042,
#   187,
#   1177,
#   4359,
#   4359,
#   878,
#   3439,
#   276,
#   316,
#   1697,
#   2277,
#   2393,
#   1413,
#   2887,
#   3989,
#   177,
#   2311,
#   2752,
#   3018,
#   2114,
#   2205,
#   2940,
#   203,
#   137,
#   712,
#   755,
#   2111,
#   2475,
#   2106,
#   2324,
#   2899,
#   3177,
#   4220,
#   4233,
#   4373,
#   224,
#   840,
#   1381,
#   1499,
#   2075,
#   2384,
#   2474,
#   2607,
#   4196,
#   2243,
#   2246,
#   2963,
#   2970,
#   1172,
#   216,
#   435,
#   1381,
#   1335,
#   1348,
#   2108,
#   2917,
#   3142,
#   3431,
#   3855,
#   550,
#   905,
#   624,
#   1429,
#   2442,
#   2451,
#   2720,
#   3312,
#   4144,
#   1254,
#   1318,
#   1572,
#   1921,
#   2148,
#   719,
#   513,
#   690,
#   1479,
#   2342,
#   3186,
#   331,
#   469,
#   697,
#   1487,
#   2075,
#   2451,
#   2647,
#   703,
#   200,
#   3167,
#   4359,
#   2133,
#   1218,
#   378,
#   2553,
#   4359,
#   276,
#   316,
#   1447,
#   1489,
#   3431,
#   3547,
#   3912,
#   3086,
#   4440,
#   4476,
#   1381,
#   1522,
#   1614,
#   9,
#   1498,
#   678,
#   4333,
#   1694,
#   2865,
#   931,
#   931,
#   3148,
#   3283,
#   3533,
#   4100,
#   1836,
#   2587,
#   924,
#   3619,
#   3740,
#   2607,
#   2655,
#   2773,
#   3086,
#   3195,
#   2704,
#   711,
#   1866,
#   2040,
#   2311,
#   2475,
#   2475,
#   3469,
#   4404,
#   279,
#   603,
#   573,
#   624,
#   2033,
#   3299,
#   3396,
#   3617,
#   3911,
#   728,
#   1611,
#   1690,
#   3779,
#   3947,
#   4231,
#   2164,
#   2183,
#   2663,
#   2903,
#   3114,
#   3988,
#   4023,
#   2781,
#   1283,
#   2196,
#   2793,
#   4068,
#   2956,
#   2793,
#   285,
#   585,
#   4359,
#   585,
#   378,
#   200,
#   2035,
#   1042,
#   4359,
#   3859,
#   3215,
#   ...]}

# %%
encoded_df = pd.DataFrame(data=newest)
encoded_df
# Out:
#         price  points  variety  winery
# 0       235.0      96       21    1759
# 2        90.0      96      143    2386
# 9        60.0      95      119     451
# 16      325.0      95       21    1689
# 19       75.0      95      119    1561
# ...       ...     ...      ...     ...
# 258117   35.0      90       21     212
# 258120   20.0      90       41     414
# 258124   35.0      90       37    1429
# 258125   35.0      90      201    1763
# 258127   22.0      90      201    1830
#
# [80460 rows x 4 columns]

# %%
# change target column to points to see how what factors contribute to points. same for cell below.
target = encoded_df["price"]

# %%
data = encoded_df.drop("price", axis=1)
feature_names = data.columns
data.head()
# Out:
#     points  variety  winery
# 0       96       21    1759
# 2       96      143    2386
# 9       95      119     451
# 16      95       21    1689
# 19      95      119    1561

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.525130499627144

# %%
# increase n_estimators to get a more accurate model.
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.5137459607258265

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.8191020271173486, 'winery'),
#  (0.11579416374547988, 'variety'),
#  (0.06510380913717151, 'points')]
