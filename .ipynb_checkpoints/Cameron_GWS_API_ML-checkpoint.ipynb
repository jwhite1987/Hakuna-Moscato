# %%
import pandas as pd
import json
import io
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
import numpy as np

# %%
file_path = '../Data/gws_cleaned_dataset.csv'
df = pd.read_csv(file_path)

# %%
df.size
# Out:
# 484605

# %%
df
# Out:
#        Unnamed: 0                                               wine  wine_id  \
# 0               0                           Chateau Margaux, Margaux    39051
# 1               1                Chateau Lafite Rothschild, Pauillac    37901
# 2               2                           Chateau Latour, Pauillac    38177
# 3               3                           Chateau Latour, Pauillac    38177
# 4               4                Chateau Lafite Rothschild, Pauillac    37901
# ...           ...                                                ...      ...
# 32302       32302  Chateau Laplagnotte-Bellevue, Saint Emilion Gr...    38089
# 32303       32303  Denis Dubourdieu, Chateau Reynon, Cadillac Cot...    50204
# 32304       32304                     Chateau Bois Pertuis, Bordeaux    32688
# 32305       32305          Chateau Renon, Cadillac Cotes De Bordeaux   148280
# 32306       32306    Cloudy Bay, Sauvignon Blanc, White, Marlborough    44199
#
#                                                wine_slug  \
# 0                                chateau-margaux-margaux
# 1                     chateau-lafite-rothschild-pauillac
# 2                                chateau-latour-pauillac
# 3                                chateau-latour-pauillac
# 4                     chateau-lafite-rothschild-pauillac
# ...                                                  ...
# 32302  chateau-laplagnotte-bellevue-saint-emilion-gra...
# 32303  denis-dubourdieu-chateau-reynon-cadillac-cotes...
# 32304                      chateau-bois-pertuis-bordeaux
# 32305           chateau-renon-cadillac-cotes-de-bordeaux
# 32306       cloudy-bay-sauvignon-blanc-white-marlborough
#
#                       appellation            appellation_slug  color  \
# 0                         Margaux                     margaux    Red
# 1                        Pauillac                    pauillac    Red
# 2                        Pauillac                    pauillac    Red
# 3                        Pauillac                    pauillac    Red
# 4                        Pauillac                    pauillac    Red
# ...                           ...                         ...    ...
# 32302     Saint Emilion Grand Cru     saint-emilion-grand-cru    Red
# 32303  Cadillac Cotes De Bordeaux  cadillac-cotes-de-bordeaux    Red
# 32304                    Bordeaux                    bordeaux    Red
# 32305  Cadillac Cotes De Bordeaux  cadillac-cotes-de-bordeaux    Red
# 32306                 Marlborough                 marlborough  White
#
#                regions      country  vintage        date  is_primeurs  score  \
# 0         ['Bordeaux']       France     1900  2016-07-29        False  98.51
# 1         ['Bordeaux']       France     1905  2018-05-01        False  84.46
# 2         ['Bordeaux']       France     1909  2011-03-31        False  91.65
# 3         ['Bordeaux']       France     1924  2018-02-01        False  91.39
# 4         ['Bordeaux']       France     1924  2018-02-01        False  81.31
# ...                ...          ...      ...         ...          ...    ...
# 32302     ['Bordeaux']       France     2020  2021-05-01         True  88.05
# 32303     ['Bordeaux']       France     2020  2021-05-01         True  87.87
# 32304     ['Bordeaux']       France     2020  2021-05-01         True  85.90
# 32305     ['Bordeaux']       France     2020  2021-05-01         True  82.59
# 32306  ['New Zealand']  New Zealand     2020  2021-04-22        False  90.03
#
#       confidence_index  journalist_count
# 0                    B                 4
# 1                    C                 3
# 2                    C                 5
# 3                    C                 3
# 4                    C                 3
# ...                ...               ...
# 32302                B                 3
# 32303               A+                 3
# 32304               C+                 3
# 32305                C                 3
# 32306                B                 3
#
# [32307 rows x 15 columns]

# %%
df.nunique()
# Out:
# Unnamed: 0          32307
# wine                 4184
# wine_id              4184
# wine_slug            4184
# appellation           343
# appellation_slug      342
# color                   3
# regions                35
# country                14
# vintage                58
# date                 2431
# is_primeurs             2
# score                2010
# confidence_index        6
# journalist_count       21
# dtype: int64

# %%
# vintage_loc = df.loc[(df['vintage']>1955) & (df['vintage'] <1980)]
vintage_loc = df.loc[(df['vintage']>1985) & (df['vintage'] <2021)]
# vintage_loc = df.loc[(df['vintage']>2000) & (df['vintage'] <2021)]

# score_loc = vintage_loc.loc[(vintage_loc['confidence_index'] == 'A+') | (vintage_loc['confidence_index'] == 'A') | (vintage_loc['confidence_index'] == 'B+') | (vintage_loc['confidence_index'] == 'B')]
# score_loc

# %%
X = vintage_loc['vintage']
Y = vintage_loc['score']

# X = score_loc['vintage']
# Y = score_loc['score']

# Y = df['vintage']
# X = df['score']
plt.scatter(X, Y)

# %%
Y_grade = df.score
X_numGrade = df.journalist_count
plt.scatter(X_numGrade, Y_grade)

# %%
df['review_year'] = pd.DatetimeIndex(df['date']).year
df
# Out:
#        Unnamed: 0                                               wine  wine_id  \
# 0               0                           Chateau Margaux, Margaux    39051
# 1               1                Chateau Lafite Rothschild, Pauillac    37901
# 2               2                           Chateau Latour, Pauillac    38177
# 3               3                           Chateau Latour, Pauillac    38177
# 4               4                Chateau Lafite Rothschild, Pauillac    37901
# ...           ...                                                ...      ...
# 32302       32302  Chateau Laplagnotte-Bellevue, Saint Emilion Gr...    38089
# 32303       32303  Denis Dubourdieu, Chateau Reynon, Cadillac Cot...    50204
# 32304       32304                     Chateau Bois Pertuis, Bordeaux    32688
# 32305       32305          Chateau Renon, Cadillac Cotes De Bordeaux   148280
# 32306       32306    Cloudy Bay, Sauvignon Blanc, White, Marlborough    44199
#
#                                                wine_slug  \
# 0                                chateau-margaux-margaux
# 1                     chateau-lafite-rothschild-pauillac
# 2                                chateau-latour-pauillac
# 3                                chateau-latour-pauillac
# 4                     chateau-lafite-rothschild-pauillac
# ...                                                  ...
# 32302  chateau-laplagnotte-bellevue-saint-emilion-gra...
# 32303  denis-dubourdieu-chateau-reynon-cadillac-cotes...
# 32304                      chateau-bois-pertuis-bordeaux
# 32305           chateau-renon-cadillac-cotes-de-bordeaux
# 32306       cloudy-bay-sauvignon-blanc-white-marlborough
#
#                       appellation            appellation_slug  color  \
# 0                         Margaux                     margaux    Red
# 1                        Pauillac                    pauillac    Red
# 2                        Pauillac                    pauillac    Red
# 3                        Pauillac                    pauillac    Red
# 4                        Pauillac                    pauillac    Red
# ...                           ...                         ...    ...
# 32302     Saint Emilion Grand Cru     saint-emilion-grand-cru    Red
# 32303  Cadillac Cotes De Bordeaux  cadillac-cotes-de-bordeaux    Red
# 32304                    Bordeaux                    bordeaux    Red
# 32305  Cadillac Cotes De Bordeaux  cadillac-cotes-de-bordeaux    Red
# 32306                 Marlborough                 marlborough  White
#
#                regions      country  vintage        date  is_primeurs  score  \
# 0         ['Bordeaux']       France     1900  2016-07-29        False  98.51
# 1         ['Bordeaux']       France     1905  2018-05-01        False  84.46
# 2         ['Bordeaux']       France     1909  2011-03-31        False  91.65
# 3         ['Bordeaux']       France     1924  2018-02-01        False  91.39
# 4         ['Bordeaux']       France     1924  2018-02-01        False  81.31
# ...                ...          ...      ...         ...          ...    ...
# 32302     ['Bordeaux']       France     2020  2021-05-01         True  88.05
# 32303     ['Bordeaux']       France     2020  2021-05-01         True  87.87
# 32304     ['Bordeaux']       France     2020  2021-05-01         True  85.90
# 32305     ['Bordeaux']       France     2020  2021-05-01         True  82.59
# 32306  ['New Zealand']  New Zealand     2020  2021-04-22        False  90.03
#
#       confidence_index  journalist_count  review_year
# 0                    B                 4         2016
# 1                    C                 3         2018
# 2                    C                 5         2011
# 3                    C                 3         2018
# 4                    C                 3         2018
# ...                ...               ...          ...
# 32302                B                 3         2021
# 32303               A+                 3         2021
# 32304               C+                 3         2021
# 32305                C                 3         2021
# 32306                B                 3         2021
#
# [32307 rows x 16 columns]

# %%
df['wine_age'] = np.subtract(df['review_year'], df['vintage']) 
# df.dtypes

# %%
df
# Out:
#        Unnamed: 0                                               wine  wine_id  \
# 0               0                           Chateau Margaux, Margaux    39051
# 1               1                Chateau Lafite Rothschild, Pauillac    37901
# 2               2                           Chateau Latour, Pauillac    38177
# 3               3                           Chateau Latour, Pauillac    38177
# 4               4                Chateau Lafite Rothschild, Pauillac    37901
# ...           ...                                                ...      ...
# 32302       32302  Chateau Laplagnotte-Bellevue, Saint Emilion Gr...    38089
# 32303       32303  Denis Dubourdieu, Chateau Reynon, Cadillac Cot...    50204
# 32304       32304                     Chateau Bois Pertuis, Bordeaux    32688
# 32305       32305          Chateau Renon, Cadillac Cotes De Bordeaux   148280
# 32306       32306    Cloudy Bay, Sauvignon Blanc, White, Marlborough    44199
#
#                                                wine_slug  \
# 0                                chateau-margaux-margaux
# 1                     chateau-lafite-rothschild-pauillac
# 2                                chateau-latour-pauillac
# 3                                chateau-latour-pauillac
# 4                     chateau-lafite-rothschild-pauillac
# ...                                                  ...
# 32302  chateau-laplagnotte-bellevue-saint-emilion-gra...
# 32303  denis-dubourdieu-chateau-reynon-cadillac-cotes...
# 32304                      chateau-bois-pertuis-bordeaux
# 32305           chateau-renon-cadillac-cotes-de-bordeaux
# 32306       cloudy-bay-sauvignon-blanc-white-marlborough
#
#                       appellation            appellation_slug  color  \
# 0                         Margaux                     margaux    Red
# 1                        Pauillac                    pauillac    Red
# 2                        Pauillac                    pauillac    Red
# 3                        Pauillac                    pauillac    Red
# 4                        Pauillac                    pauillac    Red
# ...                           ...                         ...    ...
# 32302     Saint Emilion Grand Cru     saint-emilion-grand-cru    Red
# 32303  Cadillac Cotes De Bordeaux  cadillac-cotes-de-bordeaux    Red
# 32304                    Bordeaux                    bordeaux    Red
# 32305  Cadillac Cotes De Bordeaux  cadillac-cotes-de-bordeaux    Red
# 32306                 Marlborough                 marlborough  White
#
#                regions      country  vintage        date  is_primeurs  score  \
# 0         ['Bordeaux']       France     1900  2016-07-29        False  98.51
# 1         ['Bordeaux']       France     1905  2018-05-01        False  84.46
# 2         ['Bordeaux']       France     1909  2011-03-31        False  91.65
# 3         ['Bordeaux']       France     1924  2018-02-01        False  91.39
# 4         ['Bordeaux']       France     1924  2018-02-01        False  81.31
# ...                ...          ...      ...         ...          ...    ...
# 32302     ['Bordeaux']       France     2020  2021-05-01         True  88.05
# 32303     ['Bordeaux']       France     2020  2021-05-01         True  87.87
# 32304     ['Bordeaux']       France     2020  2021-05-01         True  85.90
# 32305     ['Bordeaux']       France     2020  2021-05-01         True  82.59
# 32306  ['New Zealand']  New Zealand     2020  2021-04-22        False  90.03
#
#       confidence_index  journalist_count  review_year  wine_age
# 0                    B                 4         2016       116
# 1                    C                 3         2018       113
# 2                    C                 5         2011       102
# 3                    C                 3         2018        94
# 4                    C                 3         2018        94
# ...                ...               ...          ...       ...
# 32302                B                 3         2021         1
# 32303               A+                 3         2021         1
# 32304               C+                 3         2021         1
# 32305                C                 3         2021         1
# 32306                B                 3         2021         1
#
# [32307 rows x 17 columns]

# %%
new_df = df[['score', 'journalist_count', 'vintage', 'wine_age', 'appellation', 'country', 'confidence_index']]
new_df
# Out:
#        score  journalist_count  vintage  wine_age                 appellation  \
# 0      98.51                 4     1900       116                     Margaux
# 1      84.46                 3     1905       113                    Pauillac
# 2      91.65                 5     1909       102                    Pauillac
# 3      91.39                 3     1924        94                    Pauillac
# 4      81.31                 3     1924        94                    Pauillac
# ...      ...               ...      ...       ...                         ...
# 32302  88.05                 3     2020         1     Saint Emilion Grand Cru
# 32303  87.87                 3     2020         1  Cadillac Cotes De Bordeaux
# 32304  85.90                 3     2020         1                    Bordeaux
# 32305  82.59                 3     2020         1  Cadillac Cotes De Bordeaux
# 32306  90.03                 3     2020         1                 Marlborough
#
#            country confidence_index
# 0           France                B
# 1           France                C
# 2           France                C
# 3           France                C
# 4           France                C
# ...            ...              ...
# 32302       France                B
# 32303       France               A+
# 32304       France               C+
# 32305       France                C
# 32306  New Zealand                B
#
# [32307 rows x 7 columns]

# %%
data = new_df.values
appellation = data[:, 4]
country = data[:, 5]
confidence_index = data[:, 6]
country
# Out:
# array(['France', 'France', 'France', ..., 'France', 'France',
#        'New Zealand'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
label_encoder.fit(appellation)
encoded_appellation = label_encoder.transform(appellation)
encoded_appellation.reshape(-1,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-153-6e2a3870e704> in <module>
#       3 label_encoder.fit(appellation)
#       4 encoded_appellation = label_encoder.transform(appellation)
# ----> 5 encoded_appellation.reshape(-1,2)
#
# ValueError: cannot reshape array of size 32307 into shape (2)

# %%
X = encoded_appellation[:32306].reshape(-1,2)
y = new_df.score

# %%
y2 = [ 1 for x in range(16153)]

# %%
len(y2)
# Out:
# 16153

# %%
y.head()
# Out:
# 0    98.51
# 1    84.46
# 2    91.65
# 3    91.39
# 4    81.31
# Name: score, dtype: float64

# %%
from sklearn.tree import DecisionTreeClassifier
test = tree.DecisionTreeClassifier()
test.fit(X,y2)
# Out:
# DecisionTreeClassifier()

# %%
new_df.head()
# Out:
#    score  journalist_count  vintage  wine_age appellation country  \
# 0  98.51                 4     1900       116     Margaux  France
# 1  84.46                 3     1905       113    Pauillac  France
# 2  91.65                 5     1909       102    Pauillac  France
# 3  91.39                 3     1924        94    Pauillac  France
# 4  81.31                 3     1924        94    Pauillac  France
#
#   confidence_index
# 0                B
# 1                C
# 2                C
# 3                C
# 4                C

# %%
label_encoder.transform(new_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-151-6ba0f0c48210> in <module>
# ----> 1 label_encoder.transform(new_df)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\preprocessing\_label.py in transform(self, y)
#     131         """
#     132         check_is_fitted(self)
# --> 133         y = column_or_1d(y, warn=True)
#     134         # transform of empty array is empty array
#     135         if _num_samples(y) == 0:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     921     raise ValueError(
#     922         "y should be a 1d array, "
# --> 923         "got an array of shape {} instead.".format(shape))
#     924
#     925
#
# ValueError: y should be a 1d array, got an array of shape (32307, 7) instead.

# %%
decission

# %%
label_encoder.fit(country)
encoded_country = label_encoder.transform(country)

# %%
label_encoder.fit(confidence_index)
encoded_confidence_index = label_encoder.transform(confidence_index)

# %%
new_df.columns
# Out:
# Index(['score', 'journalist_count', 'vintage', 'wine_age', 'appellation',
#        'country', 'confidence_index'],
#       dtype='object')

# %%
newest = {
    'score': new_df['score'],
    'journalist_count': new_df['journalist_count'],
    'vintage': new_df['vintage'],
    'wine_age': new_df['wine_age'],
    'appellation': encoded_appellation.tolist(),
    'country': encoded_country.tolist(),
    'confidence_index':encoded_confidence_index.tolist()
}
newest
# Out:
# {'score': 0        98.51
#  1        84.46
#  2        91.65
#  3        91.39
#  4        81.31
#           ...
#  32302    88.05
#  32303    87.87
#  32304    85.90
#  32305    82.59
#  32306    90.03
#  Name: score, Length: 32307, dtype: float64,
#  'journalist_count': 0        4
#  1        3
#  2        5
#  3        3
#  4        3
#          ..
#  32302    3
#  32303    3
#  32304    3
#  32305    3
#  32306    3
#  Name: journalist_count, Length: 32307, dtype: int64,
#  'vintage': 0        1900
#  1        1905
#  2        1909
#  3        1924
#  4        1924
#           ...
#  32302    2020
#  32303    2020
#  32304    2020
#  32305    2020
#  32306    2020
#  Name: vintage, Length: 32307, dtype: int64,
#  'wine_age': 0        116
#  1        113
#  2        102
#  3         94
#  4         94
#          ...
#  32302      1
#  32303      1
#  32304      1
#  32305      1
#  32306      1
#  Name: wine_age, Length: 32307, dtype: int64,
#  'appellation': [185,
#   230,
#   230,
#   230,
#   230,
#   276,
#   185,
#   264,
#   264,
#   230,
#   276,
#   261,
#   230,
#   185,
#   185,
#   230,
#   276,
#   230,
#   264,
#   264,
#   261,
#   233,
#   276,
#   260,
#   230,
#   233,
#   276,
#   260,
#   230,
#   261,
#   230,
#   234,
#   233,
#   233,
#   264,
#   230,
#   234,
#   23,
#   230,
#   260,
#   276,
#   234,
#   260,
#   166,
#   260,
#   185,
#   234,
#   261,
#   260,
#   261,
#   230,
#   260,
#   234,
#   230,
#   230,
#   23,
#   166,
#   233,
#   234,
#   234,
#   276,
#   233,
#   234,
#   230,
#   74,
#   234,
#   234,
#   233,
#   260,
#   260,
#   264,
#   233,
#   230,
#   230,
#   230,
#   261,
#   230,
#   260,
#   276,
#   17,
#   126,
#   230,
#   185,
#   185,
#   230,
#   276,
#   233,
#   233,
#   260,
#   234,
#   260,
#   261,
#   234,
#   234,
#   264,
#   230,
#   234,
#   261,
#   234,
#   260,
#   230,
#   126,
#   230,
#   219,
#   13,
#   23,
#   260,
#   260,
#   230,
#   234,
#   234,
#   234,
#   253,
#   250,
#   234,
#   185,
#   261,
#   271,
#   23,
#   17,
#   230,
#   234,
#   260,
#   230,
#   276,
#   233,
#   219,
#   13,
#   126,
#   264,
#   233,
#   126,
#   233,
#   219,
#   234,
#   230,
#   219,
#   74,
#   166,
#   126,
#   276,
#   233,
#   219,
#   219,
#   219,
#   271,
#   166,
#   103,
#   233,
#   234,
#   234,
#   264,
#   260,
#   233,
#   230,
#   276,
#   264,
#   230,
#   260,
#   234,
#   260,
#   230,
#   260,
#   261,
#   233,
#   260,
#   230,
#   234,
#   264,
#   36,
#   261,
#   260,
#   234,
#   219,
#   219,
#   230,
#   233,
#   234,
#   264,
#   264,
#   74,
#   230,
#   233,
#   23,
#   126,
#   51,
#   185,
#   264,
#   185,
#   13,
#   233,
#   276,
#   219,
#   230,
#   276,
#   230,
#   234,
#   234,
#   74,
#   113,
#   36,
#   261,
#   264,
#   233,
#   219,
#   219,
#   13,
#   23,
#   219,
#   126,
#   219,
#   230,
#   276,
#   260,
#   36,
#   166,
#   276,
#   233,
#   261,
#   233,
#   230,
#   271,
#   219,
#   234,
#   167,
#   253,
#   219,
#   234,
#   264,
#   185,
#   185,
#   230,
#   260,
#   185,
#   234,
#   219,
#   233,
#   230,
#   219,
#   219,
#   151,
#   36,
#   261,
#   276,
#   19,
#   260,
#   260,
#   230,
#   17,
#   219,
#   219,
#   113,
#   219,
#   219,
#   80,
#   125,
#   113,
#   126,
#   219,
#   276,
#   103,
#   13,
#   219,
#   219,
#   264,
#   230,
#   233,
#   251,
#   260,
#   233,
#   264,
#   261,
#   230,
#   233,
#   23,
#   261,
#   260,
#   260,
#   233,
#   219,
#   219,
#   264,
#   230,
#   230,
#   230,
#   154,
#   36,
#   219,
#   74,
#   74,
#   260,
#   13,
#   113,
#   113,
#   234,
#   234,
#   276,
#   126,
#   219,
#   185,
#   185,
#   260,
#   264,
#   233,
#   219,
#   234,
#   299,
#   219,
#   260,
#   13,
#   126,
#   276,
#   113,
#   260,
#   230,
#   230,
#   230,
#   219,
#   230,
#   234,
#   233,
#   233,
#   261,
#   264,
#   230,
#   230,
#   260,
#   264,
#   261,
#   113,
#   251,
#   36,
#   13,
#   219,
#   166,
#   260,
#   260,
#   233,
#   271,
#   185,
#   74,
#   276,
#   234,
#   234,
#   264,
#   74,
#   233,
#   233,
#   264,
#   149,
#   185,
#   230,
#   234,
#   260,
#   260,
#   260,
#   113,
#   260,
#   260,
#   264,
#   233,
#   234,
#   113,
#   264,
#   230,
#   234,
#   230,
#   264,
#   261,
#   261,
#   260,
#   234,
#   230,
#   261,
#   234,
#   234,
#   17,
#   219,
#   230,
#   234,
#   234,
#   264,
#   185,
#   230,
#   264,
#   234,
#   261,
#   233,
#   264,
#   233,
#   234,
#   233,
#   260,
#   167,
#   264,
#   230,
#   185,
#   234,
#   233,
#   230,
#   154,
#   185,
#   13,
#   100,
#   260,
#   230,
#   260,
#   260,
#   149,
#   233,
#   276,
#   230,
#   233,
#   230,
#   230,
#   264,
#   36,
#   74,
#   74,
#   261,
#   260,
#   234,
#   260,
#   260,
#   185,
#   234,
#   264,
#   264,
#   234,
#   290,
#   261,
#   185,
#   260,
#   113,
#   234,
#   276,
#   207,
#   151,
#   264,
#   126,
#   149,
#   230,
#   234,
#   185,
#   185,
#   260,
#   260,
#   74,
#   261,
#   261,
#   234,
#   260,
#   233,
#   260,
#   260,
#   149,
#   264,
#   185,
#   185,
#   185,
#   260,
#   260,
#   234,
#   233,
#   185,
#   230,
#   264,
#   230,
#   234,
#   230,
#   185,
#   149,
#   261,
#   233,
#   234,
#   234,
#   185,
#   185,
#   260,
#   234,
#   260,
#   260,
#   192,
#   185,
#   185,
#   185,
#   251,
#   185,
#   260,
#   23,
#   185,
#   230,
#   260,
#   219,
#   264,
#   234,
#   260,
#   234,
#   233,
#   230,
#   264,
#   261,
#   264,
#   230,
#   185,
#   230,
#   276,
#   185,
#   260,
#   74,
#   154,
#   185,
#   13,
#   234,
#   38,
#   260,
#   234,
#   276,
#   260,
#   276,
#   234,
#   113,
#   230,
#   233,
#   234,
#   260,
#   264,
#   217,
#   233,
#   260,
#   113,
#   80,
#   290,
#   260,
#   276,
#   276,
#   230,
#   4,
#   151,
#   113,
#   233,
#   234,
#   126,
#   276,
#   264,
#   276,
#   233,
#   264,
#   74,
#   261,
#   74,
#   185,
#   233,
#   234,
#   260,
#   185,
#   230,
#   185,
#   261,
#   233,
#   260,
#   264,
#   149,
#   185,
#   260,
#   23,
#   230,
#   230,
#   230,
#   185,
#   230,
#   219,
#   264,
#   219,
#   230,
#   154,
#   234,
#   271,
#   219,
#   36,
#   314,
#   219,
#   290,
#   234,
#   113,
#   126,
#   13,
#   276,
#   233,
#   219,
#   264,
#   230,
#   185,
#   233,
#   230,
#   230,
#   234,
#   74,
#   260,
#   219,
#   154,
#   264,
#   230,
#   264,
#   233,
#   234,
#   234,
#   219,
#   185,
#   234,
#   234,
#   167,
#   234,
#   234,
#   230,
#   185,
#   260,
#   234,
#   74,
#   185,
#   260,
#   89,
#   38,
#   234,
#   261,
#   93,
#   260,
#   271,
#   234,
#   264,
#   251,
#   233,
#   36,
#   264,
#   233,
#   260,
#   261,
#   261,
#   260,
#   74,
#   260,
#   332,
#   290,
#   230,
#   230,
#   233,
#   185,
#   234,
#   233,
#   113,
#   292,
#   219,
#   264,
#   74,
#   74,
#   74,
#   151,
#   113,
#   23,
#   264,
#   126,
#   70,
#   219,
#   219,
#   80,
#   260,
#   230,
#   276,
#   299,
#   219,
#   113,
#   260,
#   264,
#   251,
#   233,
#   276,
#   151,
#   185,
#   74,
#   74,
#   35,
#   264,
#   233,
#   233,
#   149,
#   70,
#   230,
#   260,
#   260,
#   260,
#   185,
#   88,
#   80,
#   261,
#   80,
#   264,
#   260,
#   230,
#   264,
#   185,
#   185,
#   219,
#   264,
#   234,
#   276,
#   219,
#   219,
#   219,
#   233,
#   257,
#   126,
#   264,
#   261,
#   113,
#   219,
#   230,
#   230,
#   230,
#   233,
#   234,
#   233,
#   233,
#   154,
#   234,
#   185,
#   234,
#   154,
#   299,
#   234,
#   185,
#   19,
#   74,
#   260,
#   219,
#   288,
#   233,
#   233,
#   36,
#   219,
#   234,
#   260,
#   261,
#   115,
#   260,
#   219,
#   52,
#   153,
#   290,
#   164,
#   13,
#   35,
#   219,
#   292,
#   219,
#   230,
#   299,
#   260,
#   126,
#   233,
#   219,
#   219,
#   219,
#   219,
#   219,
#   219,
#   219,
#   219,
#   225,
#   271,
#   230,
#   233,
#   233,
#   230,
#   219,
#   219,
#   299,
#   264,
#   264,
#   260,
#   264,
#   2,
#   230,
#   276,
#   113,
#   113,
#   219,
#   154,
#   219,
#   219,
#   219,
#   219,
#   219,
#   289,
#   160,
#   234,
#   233,
#   233,
#   234,
#   23,
#   230,
#   233,
#   183,
#   192,
#   149,
#   185,
#   233,
#   264,
#   251,
#   169,
#   149,
#   260,
#   6,
#   61,
#   260,
#   234,
#   261,
#   260,
#   260,
#   260,
#   185,
#   260,
#   230,
#   260,
#   233,
#   260,
#   233,
#   264,
#   260,
#   264,
#   233,
#   233,
#   260,
#   260,
#   185,
#   261,
#   260,
#   230,
#   230,
#   264,
#   233,
#   261,
#   233,
#   185,
#   233,
#   185,
#   261,
#   264,
#   149,
#   100,
#   251,
#   219,
#   219,
#   230,
#   234,
#   260,
#   234,
#   185,
#   234,
#   234,
#   230,
#   261,
#   185,
#   260,
#   234,
#   234,
#   74,
#   250,
#   95,
#   74,
#   74,
#   74,
#   233,
#   207,
#   185,
#   261,
#   234,
#   233,
#   213,
#   261,
#   149,
#   261,
#   149,
#   230,
#   185,
#   149,
#   149,
#   185,
#   59,
#   185,
#   260,
#   177,
#   234,
#   116,
#   234,
#   234,
#   288,
#   261,
#   192,
#   177,
#   261,
#   234,
#   230,
#   234,
#   234,
#   234,
#   234,
#   260,
#   260,
#   233,
#   185,
#   230,
#   185,
#   213,
#   234,
#   260,
#   261,
#   185,
#   135,
#   135,
#   261,
#   233,
#   192,
#   233,
#   233,
#   74,
#   264,
#   233,
#   185,
#   113,
#   234,
#   230,
#   233,
#   233,
#   101,
#   219,
#   260,
#   261,
#   219,
#   80,
#   149,
#   261,
#   230,
#   219,
#   264,
#   264,
#   185,
#   230,
#   234,
#   276,
#   230,
#   185,
#   200,
#   260,
#   151,
#   234,
#   185,
#   261,
#   20,
#   217,
#   264,
#   185,
#   219,
#   74,
#   74,
#   233,
#   260,
#   264,
#   80,
#   170,
#   234,
#   230,
#   185,
#   230,
#   260,
#   276,
#   74,
#   233,
#   185,
#   189,
#   154,
#   234,
#   160,
#   71,
#   38,
#   230,
#   149,
#   233,
#   185,
#   299,
#   74,
#   80,
#   233,
#   233,
#   260,
#   74,
#   74,
#   271,
#   230,
#   74,
#   74,
#   ...],
#  'country': [4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   13,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   1,
#   1,
#   4,
#   4,
#   1,
#   4,
#   13,
#   4,
#   4,
#   13,
#   4,
#   4,
#   1,
#   4,
#   4,
#   13,
#   13,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   6,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   13,
#   13,
#   1,
#   4,
#   13,
#   1,
#   13,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   13,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   13,
#   13,
#   4,
#   6,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   6,
#   13,
#   13,
#   4,
#   13,
#   13,
#   4,
#   4,
#   4,
#   1,
#   13,
#   4,
#   4,
#   1,
#   13,
#   13,
#   4,
#   4,
#   4,
#   12,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   13,
#   6,
#   13,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   6,
#   13,
#   4,
#   1,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   12,
#   6,
#   1,
#   13,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   1,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   12,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   13,
#   4,
#   13,
#   4,
#   13,
#   13,
#   6,
#   2,
#   13,
#   13,
#   4,
#   4,
#   1,
#   1,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   12,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   6,
#   13,
#   4,
#   4,
#   4,
#   12,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   13,
#   13,
#   13,
#   4,
#   13,
#   1,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   13,
#   6,
#   4,
#   4,
#   6,
#   4,
#   4,
#   13,
#   1,
#   4,
#   4,
#   6,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   6,
#   13,
#   13,
#   13,
#   1,
#   6,
#   13,
#   13,
#   13,
#   4,
#   6,
#   4,
#   1,
#   4,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   13,
#   13,
#   6,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   12,
#   6,
#   4,
#   4,
#   6,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   12,
#   13,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   6,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   13,
#   4,
#   4,
#   4,
#   ...],
#  'confidence_index': [2,
#   4,
#   4,
#   4,
#   4,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   5,
#   2,
#   4,
#   4,
#   4,
#   4,
#   2,
#   5,
#   4,
#   2,
#   4,
#   4,
#   2,
#   5,
#   5,
#   4,
#   5,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   0,
#   4,
#   2,
#   4,
#   5,
#   5,
#   5,
#   4,
#   4,
#   1,
#   2,
#   5,
#   5,
#   5,
#   4,
#   4,
#   2,
#   4,
#   3,
#   3,
#   4,
#   2,
#   5,
#   2,
#   4,
#   5,
#   4,
#   2,
#   4,
#   4,
#   4,
#   5,
#   2,
#   5,
#   2,
#   0,
#   1,
#   5,
#   4,
#   4,
#   2,
#   3,
#   4,
#   0,
#   1,
#   2,
#   0,
#   2,
#   5,
#   0,
#   4,
#   2,
#   2,
#   4,
#   5,
#   2,
#   5,
#   4,
#   5,
#   5,
#   2,
#   1,
#   4,
#   4,
#   4,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   2,
#   0,
#   4,
#   2,
#   5,
#   5,
#   4,
#   2,
#   5,
#   4,
#   4,
#   0,
#   2,
#   2,
#   4,
#   2,
#   5,
#   4,
#   2,
#   3,
#   4,
#   4,
#   4,
#   4,
#   3,
#   4,
#   2,
#   4,
#   4,
#   4,
#   2,
#   4,
#   4,
#   4,
#   2,
#   4,
#   4,
#   2,
#   4,
#   5,
#   5,
#   5,
#   2,
#   2,
#   5,
#   4,
#   5,
#   4,
#   5,
#   2,
#   4,
#   4,
#   3,
#   2,
#   1,
#   1,
#   3,
#   4,
#   5,
#   4,
#   4,
#   0,
#   4,
#   5,
#   3,
#   4,
#   0,
#   4,
#   5,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   2,
#   5,
#   4,
#   4,
#   5,
#   5,
#   2,
#   2,
#   2,
#   5,
#   5,
#   5,
#   4,
#   4,
#   4,
#   2,
#   2,
#   4,
#   5,
#   3,
#   4,
#   4,
#   5,
#   5,
#   5,
#   4,
#   4,
#   5,
#   4,
#   2,
#   4,
#   4,
#   4,
#   4,
#   1,
#   4,
#   4,
#   4,
#   2,
#   2,
#   4,
#   5,
#   2,
#   3,
#   2,
#   5,
#   4,
#   5,
#   2,
#   5,
#   5,
#   4,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   5,
#   5,
#   4,
#   4,
#   0,
#   4,
#   0,
#   4,
#   4,
#   2,
#   4,
#   2,
#   4,
#   4,
#   3,
#   4,
#   0,
#   5,
#   2,
#   4,
#   4,
#   1,
#   5,
#   4,
#   2,
#   3,
#   5,
#   2,
#   4,
#   4,
#   2,
#   5,
#   4,
#   5,
#   4,
#   5,
#   2,
#   4,
#   5,
#   2,
#   2,
#   3,
#   4,
#   2,
#   4,
#   2,
#   5,
#   4,
#   5,
#   5,
#   4,
#   2,
#   3,
#   4,
#   4,
#   4,
#   1,
#   5,
#   5,
#   4,
#   4,
#   2,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   2,
#   4,
#   0,
#   4,
#   4,
#   4,
#   2,
#   1,
#   4,
#   5,
#   2,
#   2,
#   4,
#   5,
#   5,
#   2,
#   4,
#   4,
#   5,
#   5,
#   5,
#   2,
#   4,
#   4,
#   5,
#   4,
#   0,
#   5,
#   2,
#   4,
#   4,
#   4,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   2,
#   3,
#   0,
#   0,
#   2,
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   2,
#   2,
#   3,
#   2,
#   2,
#   2,
#   2,
#   3,
#   3,
#   2,
#   2,
#   2,
#   4,
#   2,
#   2,
#   4,
#   2,
#   4,
#   2,
#   4,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   5,
#   4,
#   2,
#   5,
#   2,
#   1,
#   2,
#   5,
#   2,
#   5,
#   3,
#   2,
#   4,
#   2,
#   2,
#   5,
#   2,
#   1,
#   2,
#   2,
#   4,
#   3,
#   5,
#   4,
#   3,
#   2,
#   2,
#   5,
#   3,
#   2,
#   2,
#   2,
#   4,
#   5,
#   4,
#   2,
#   4,
#   3,
#   2,
#   5,
#   5,
#   5,
#   2,
#   3,
#   4,
#   0,
#   3,
#   4,
#   5,
#   4,
#   5,
#   5,
#   4,
#   2,
#   4,
#   2,
#   5,
#   4,
#   5,
#   4,
#   2,
#   4,
#   5,
#   5,
#   5,
#   4,
#   2,
#   2,
#   4,
#   2,
#   5,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   2,
#   5,
#   0,
#   2,
#   4,
#   3,
#   2,
#   5,
#   2,
#   5,
#   4,
#   5,
#   2,
#   4,
#   2,
#   0,
#   5,
#   2,
#   2,
#   4,
#   2,
#   3,
#   2,
#   4,
#   5,
#   4,
#   2,
#   5,
#   2,
#   2,
#   2,
#   2,
#   4,
#   2,
#   2,
#   5,
#   4,
#   3,
#   4,
#   5,
#   5,
#   5,
#   2,
#   4,
#   5,
#   4,
#   2,
#   4,
#   4,
#   5,
#   2,
#   4,
#   2,
#   2,
#   4,
#   4,
#   5,
#   5,
#   2,
#   4,
#   5,
#   1,
#   2,
#   2,
#   1,
#   4,
#   4,
#   4,
#   3,
#   5,
#   4,
#   2,
#   3,
#   2,
#   2,
#   2,
#   1,
#   2,
#   5,
#   2,
#   3,
#   5,
#   4,
#   4,
#   5,
#   4,
#   2,
#   2,
#   4,
#   4,
#   4,
#   2,
#   4,
#   5,
#   4,
#   2,
#   1,
#   4,
#   4,
#   4,
#   5,
#   2,
#   5,
#   5,
#   0,
#   5,
#   5,
#   0,
#   5,
#   0,
#   2,
#   0,
#   2,
#   2,
#   1,
#   4,
#   2,
#   4,
#   5,
#   5,
#   2,
#   3,
#   5,
#   0,
#   2,
#   1,
#   4,
#   5,
#   5,
#   5,
#   3,
#   3,
#   4,
#   4,
#   2,
#   4,
#   4,
#   2,
#   3,
#   4,
#   4,
#   5,
#   2,
#   2,
#   4,
#   2,
#   2,
#   4,
#   5,
#   2,
#   0,
#   5,
#   5,
#   2,
#   2,
#   2,
#   4,
#   3,
#   5,
#   0,
#   5,
#   4,
#   2,
#   5,
#   2,
#   2,
#   5,
#   0,
#   2,
#   5,
#   2,
#   2,
#   2,
#   0,
#   2,
#   5,
#   4,
#   5,
#   4,
#   3,
#   4,
#   4,
#   3,
#   4,
#   1,
#   4,
#   1,
#   4,
#   4,
#   2,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   0,
#   5,
#   2,
#   4,
#   5,
#   5,
#   0,
#   5,
#   4,
#   4,
#   5,
#   5,
#   2,
#   1,
#   1,
#   2,
#   2,
#   4,
#   2,
#   2,
#   4,
#   5,
#   4,
#   5,
#   3,
#   2,
#   4,
#   2,
#   4,
#   2,
#   0,
#   2,
#   2,
#   2,
#   2,
#   1,
#   4,
#   5,
#   3,
#   2,
#   2,
#   0,
#   4,
#   3,
#   5,
#   2,
#   2,
#   2,
#   1,
#   5,
#   0,
#   1,
#   2,
#   2,
#   2,
#   5,
#   4,
#   5,
#   2,
#   0,
#   2,
#   3,
#   0,
#   3,
#   5,
#   2,
#   5,
#   4,
#   1,
#   5,
#   2,
#   2,
#   4,
#   3,
#   3,
#   2,
#   0,
#   4,
#   2,
#   3,
#   4,
#   4,
#   2,
#   3,
#   2,
#   2,
#   5,
#   2,
#   2,
#   2,
#   5,
#   2,
#   2,
#   2,
#   2,
#   4,
#   5,
#   4,
#   2,
#   2,
#   5,
#   1,
#   2,
#   2,
#   0,
#   5,
#   2,
#   4,
#   2,
#   0,
#   0,
#   2,
#   3,
#   1,
#   2,
#   0,
#   2,
#   1,
#   5,
#   2,
#   2,
#   5,
#   4,
#   5,
#   2,
#   3,
#   5,
#   2,
#   5,
#   2,
#   5,
#   4,
#   2,
#   1,
#   5,
#   3,
#   0,
#   0,
#   2,
#   0,
#   2,
#   0,
#   4,
#   0,
#   2,
#   1,
#   2,
#   2,
#   5,
#   2,
#   3,
#   1,
#   2,
#   2,
#   3,
#   3,
#   0,
#   2,
#   1,
#   4,
#   4,
#   5,
#   4,
#   3,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   0,
#   4,
#   5,
#   4,
#   2,
#   2,
#   2,
#   3,
#   3,
#   2,
#   3,
#   3,
#   4,
#   5,
#   5,
#   5,
#   5,
#   4,
#   0,
#   3,
#   2,
#   5,
#   0,
#   3,
#   4,
#   5,
#   0,
#   0,
#   1,
#   2,
#   3,
#   4,
#   4,
#   4,
#   5,
#   4,
#   5,
#   5,
#   4,
#   5,
#   4,
#   4,
#   4,
#   3,
#   5,
#   2,
#   4,
#   0,
#   4,
#   4,
#   4,
#   4,
#   5,
#   2,
#   2,
#   5,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   4,
#   0,
#   2,
#   2,
#   4,
#   4,
#   2,
#   0,
#   4,
#   4,
#   4,
#   5,
#   5,
#   2,
#   2,
#   3,
#   2,
#   2,
#   5,
#   0,
#   0,
#   0,
#   2,
#   3,
#   3,
#   2,
#   5,
#   2,
#   5,
#   2,
#   0,
#   3,
#   0,
#   3,
#   2,
#   2,
#   3,
#   5,
#   3,
#   0,
#   2,
#   3,
#   2,
#   2,
#   4,
#   0,
#   2,
#   3,
#   5,
#   3,
#   5,
#   2,
#   2,
#   2,
#   2,
#   0,
#   1,
#   5,
#   2,
#   2,
#   2,
#   0,
#   3,
#   5,
#   3,
#   0,
#   2,
#   5,
#   2,
#   2,
#   2,
#   2,
#   3,
#   3,
#   2,
#   4,
#   3,
#   2,
#   5,
#   3,
#   2,
#   2,
#   5,
#   2,
#   2,
#   2,
#   3,
#   3,
#   2,
#   ...]}

# %%
encoded_df = pd.DataFrame(data=newest)
encoded_df
# Out:
#        score  journalist_count  vintage  wine_age  appellation  country  \
# 0      98.51                 4     1900       116          185        4
# 1      84.46                 3     1905       113          230        4
# 2      91.65                 5     1909       102          230        4
# 3      91.39                 3     1924        94          230        4
# 4      81.31                 3     1924        94          230        4
# ...      ...               ...      ...       ...          ...      ...
# 32302  88.05                 3     2020         1          260        4
# 32303  87.87                 3     2020         1           54        4
# 32304  85.90                 3     2020         1           40        4
# 32305  82.59                 3     2020         1           54        4
# 32306  90.03                 3     2020         1          186        8
#
#        confidence_index
# 0                     2
# 1                     4
# 2                     4
# 3                     4
# 4                     4
# ...                 ...
# 32302                 2
# 32303                 1
# 32304                 5
# 32305                 4
# 32306                 2
#
# [32307 rows x 7 columns]

# %%
plt.scatter(encoded_df.score, encoded_df.wine_age)

# %%
encoded_df.dtypes
# Out:
# score               float64
# journalist_count      int64
# vintage               int64
# wine_age              int64
# dtype: object

# %%
target = encoded_df["score"]

# %%
data = encoded_df.drop("score", axis=1)
feature_names = data.columns
data.head()
# Out:
#    journalist_count  vintage  wine_age
# 0                 4     1900       116
# 1                 3     1905       113
# 2                 5     1909       102
# 3                 3     1924        94
# 4                 3     1924        94

# %%
data.dtypes
# Out:
# journalist_count    int64
# vintage             int64
# wine_age            int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
test = tree.DecisionTreeClassifier()

# %%
test.fit(encoded_appellation, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-123-80eac9cd0372> in <module>
# ----> 1 test.fit(encoded_appellation, target)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     905             sample_weight=sample_weight,
#     906             check_input=check_input,
# --> 907             X_idx_sorted=X_idx_sorted)
#     908         return self
#     909
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     157             X, y = self._validate_data(X, y,
#     158                                        validate_separately=(check_X_params,
# --> 159                                                             check_y_params))
#     160             if issparse(X):
#     161                 X.sort_indices()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     428                 # :(
#     429                 check_X_params, check_y_params = validate_separately
# --> 430                 X = check_array(X, **check_X_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#     697                     "your data has a single feature or array.reshape(1, -1) "
# --> 698                     "if it contains a single sample.".format(array))
#     699
#     700         # make sure we actually converted to numeric:
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[185. 230. 230. ...  40.  54. 186.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-115-138c78d3029c> in <module>
#       1 from sklearn import tree
#       2 clf = tree.DecisionTreeClassifier()
# ----> 3 clf = clf.fit(X_train, y_train)
#       4 clf.score(X_test, y_test)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     905             sample_weight=sample_weight,
#     906             check_input=check_input,
# --> 907             X_idx_sorted=X_idx_sorted)
#     908         return self
#     909
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     189
#     190         if is_classification:
# --> 191             check_classification_targets(y)
#     192             y = np.copy(y)
#     193
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(n_estimators=1000)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.14726992933060135

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=1000)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-35c710f6ff10> in <module>
#       1 from sklearn.ensemble import RandomForestClassifier
#       2 rf = RandomForestClassifier(n_estimators=1000)
# ----> 3 rf = rf.fit(X_train, y_train)
#       4 rf.score(X_test, y_test)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     329         self.n_outputs_ = y.shape[1]
#     330
# --> 331         y, expanded_class_weight = self._validate_y_class_weight(y)
#     332
#     333         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_forest.py in _validate_y_class_weight(self, y)
#     557
#     558     def _validate_y_class_weight(self, y):
# --> 559         check_classification_targets(y)
#     560
#     561         y = np.copy(y)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-d556f1b21f2f> in <module>
# ----> 1 sorted(zip(rf.feature_importances_, feature_names), reverse=True)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\ensemble\_forest.py in feature_importances_(self)
#     448                                    **_joblib_parallel_args(prefer='threads'))(
#     449             delayed(getattr)(tree, 'feature_importances_')
# --> 450             for tree in self.estimators_ if tree.tree_.node_count > 1)
#     451
#     452         if not all_importances:
#
# AttributeError: 'RandomForestClassifier' object has no attribute 'estimators_'

# %%
test = tree.DecisionTreeClassifier()
test.fit(encoded_df.confidence_index, encoded_df.score)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-138-49ab02e70b8b> in <module>
#       1 test = tree.DecisionTreeClassifier()
# ----> 2 test.fit(encoded_df.confidence_index, encoded_df.score)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     905             sample_weight=sample_weight,
#     906             check_input=check_input,
# --> 907             X_idx_sorted=X_idx_sorted)
#     908         return self
#     909
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     157             X, y = self._validate_data(X, y,
#     158                                        validate_separately=(check_X_params,
# --> 159                                                             check_y_params))
#     160             if issparse(X):
#     161                 X.sort_indices()
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     428                 # :(
#     429                 check_X_params, check_y_params = validate_separately
# --> 430                 X = check_array(X, **check_X_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     696                     "Reshape your data either using array.reshape(-1, 1) if "
#     697                     "your data has a single feature or array.reshape(1, -1) "
# --> 698                     "if it contains a single sample.".format(array))
#     699
#     700         # make sure we actually converted to numeric:
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[2. 4. 4. ... 5. 4. 2.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
encoded_df.confidence_index
# Out:
# 0        2
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 32302    2
# 32303    1
# 32304    5
# 32305    4
# 32306    2
# Name: confidence_index, Length: 32307, dtype: int64
