# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json
from pprint import pprint

# %%
# from urllib.request import urlopen, Request

# headers = {
#   'Accept': 'application/json',
#   'Authorization': 'Token 676a1a3b84610b9bef1c18ba10936d98ba5c3633'
# }
# request = Request('https://api.globalwinescore.com/globalwinescores/latest/?wine_id=&vintage=&color=&is_primeurs=&lwin=&lwin_11=&limit=&offset=&ordering=', headers=headers)

# response_body = urlopen(request).read()
# print(response_body)

# %%
url = 'https://en.wikipedia.org/wiki/List_of_grape_varieties'

# %%
tables = pd.read_html(url)
tables
# Out:
# [                                   Common Name(s)  \
#  0                                         Abbuoto
#  1                                        Abouriou
#  2                                   Alexandroouli
#  3                                       Akhasheni
#  4                                         Abrusco
#  ..                                            ...
#  421                                Wrothham Pinot
#  422                                     Xinomavro
#  423                                     Žametovka
#  424  Zinfandel / Crljenak Kaštelanski / Primitivo
#  425           Zweigelt / Zweigeltrebe / Rotburger
#
#                                            All Synonyms  \
#  0                                       Aboto, Cecubo.
#  1    Beaujolais, Early Burgunder, Early Burgundy, G...
#  2    Aleksandroouly, Aleksandrouli, Aleksandrouli s...
#  3                                          Akhashenuli
#  4    Abrostalo, Abrostine, Abrostino, Abrusco nero,...
# ...

# %%
type(tables)
# Out:
# list

# %%
whites_df = tables[1]                 
whites_df.head(10)
# Out:
#              Common Name(s)  \
# 0                 Adalmiina
# 1                  Addoraca
# 2                 Agh Shani
# 3  Aidani / Aidini / Aedani
# 4                     Airén
# 5        Alarije / Alarijen
# 6                 Albalonga
# 7                    Albana
# 8                 Albanella
# 9          Albanello bianco
#
#                                         All Synonyms   Country of origin  \
# 0                         Aldemina, Elmer Swenson[3]                 USA
# 1                                            Odoacra               Italy
# 2                                                NaN          Azerbaijan
# 3  Aidani, Aspro, Aedano, Aedani, Aidano, Aspedan...  Greece (Santorini)
# 4  Aiden, Blancon, Forcallada, Forcallat, Forcall...               Spain
# 5                                                NaN               Spain
# 6                                                NaN             Germany
# ...

# %%
whites_df.to_csv("whitewines.csv", index=False, header=True)

# %%
reds_df = tables[0]                 
reds_df.head(10)
# Out:
#   Common Name(s)                                       All Synonyms  \
# 0        Abbuoto                                     Aboto, Cecubo.
# 1       Abouriou  Beaujolais, Early Burgunder, Early Burgundy, G...
# 2  Alexandroouli  Aleksandroouly, Aleksandrouli, Aleksandrouli s...
# 3      Akhasheni                                        Akhashenuli
# 4        Abrusco  Abrostalo, Abrostine, Abrostino, Abrusco nero,...
# 5         Acolon                                                NaN
# 6     Ada Karasi  Adakarasi, Adakarassy, Avsa adasi, Avsa island...
# 7    Affenthaler  Affenthaler schwarzblau, Affenthaler blauer, B...
# 8    Agiorgitiko  Aghiorghitico, Aghiorghitiko, Nemeas Mavro, Ne...
# 9      Aglianico  Aglianco di puglia, Aglianica, Aglianichella, ...
#
#                 Country of origin  \
# 0                    Italy, Lazio
# 1               France, Southwest
# 2                         Georgia
# 3          Georgia Eastern parts.
# 4                  Italy, Tuscany
# ...

# %%
reds_df.to_csv("redwines.csv", index=False, header=True)
